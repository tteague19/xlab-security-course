# %%
# IF YOU ARE IN COLAB OR HAVE NOT INSTALLED `xlab-security`
# !pip install xlab-security # should not take more than a minute or two to run
# Out:
# Collecting xlab-security
#   Downloading xlab_security-0.1.13-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: torch>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from xlab-security) (2.9.0+cpu)
# Requirement already satisfied: torchvision>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from xlab-security) (0.24.0+cpu)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from xlab-security) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from xlab-security) (3.10.0)
# Requirement already satisfied: pytest>=6.0 in /usr/local/lib/python3.12/dist-packages (from xlab-security) (8.4.2)
# Requirement already satisfied: openai>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from xlab-security) (2.12.0)
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from xlab-security) (11.3.0)
# Requirement already satisfied: hf_xet in /usr/local/lib/python3.12/dist-packages (from xlab-security) (1.2.0)
# Requirement already satisfied: huggingface_hub>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from xlab-security) (0.36.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.15.0->xlab-security) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.15.0->xlab-security) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.15.0->xlab-security) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.15.0->xlab-security) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.15.0->xlab-security) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.15.0->xlab-security) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.15.0->xlab-security) (4.15.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->xlab-security) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->xlab-security) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->xlab-security) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->xlab-security) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->xlab-security) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->xlab-security) (2.9.0.post0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.0.0->xlab-security) (4.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.0.0->xlab-security) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.0.0->xlab-security) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.0.0->xlab-security) (0.12.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.0.0->xlab-security) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai>=1.0.0->xlab-security) (1.3.1)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.12/dist-packages (from pytest>=6.0->xlab-security) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest>=6.0->xlab-security) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from pytest>=6.0->xlab-security) (2.19.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->xlab-security) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->xlab-security) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->xlab-security) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->xlab-security) (3.1.6)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai>=1.0.0->xlab-security) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai>=1.0.0->xlab-security) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai>=1.0.0->xlab-security) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.0.0->xlab-security) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai>=1.0.0->xlab-security) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai>=1.0.0->xlab-security) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai>=1.0.0->xlab-security) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->xlab-security) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.9.0->xlab-security) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.9.0->xlab-security) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.15.0->xlab-security) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.15.0->xlab-security) (2.5.0)
# Downloading xlab_security-0.1.13-py3-none-any.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 12.3 MB/s eta 0:00:00
# Installing collected packages: xlab-security
# Successfully installed xlab-security-0.1.13

# %%
import torch
import xlab
import matplotlib.pyplot as plt

device = xlab.utils.get_best_device()

# %% [markdown]
# ## Loading the MNIST Dataset
#
# Before we begin the attack, let's take a look at our data and the surrogate models we will be using for this notebook. First, you can see that the `xlab-security` package provides you with `xlab.utils.load_mnist_test_samples` which you can use to load members of the MNIST handwritten digit test set.

# %%
mnist_images, mnist_labels = xlab.utils.load_mnist_test_samples(100)
print(f"Images shape: {mnist_images.shape}")
print(f"Labels shape: {mnist_labels.shape}")
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 59.2MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 1.69MB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 15.1MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 10.9MB/s]
# Images shape: torch.Size([100, 1, 28, 28])
# Labels shape: torch.Size([100])

# %% [markdown]
# We also provide you with `xlab.utils.show_grayscale_image` to plot MNIST images. You can change the `image_index` below to explore different images in the dataset.

# %%
image_index = 0
xlab.utils.show_grayscale_image(
    mnist_images[image_index], title=f"label={mnist_labels[image_index]}"
)

# %% [markdown]
# ## Loading White-Box Models
#
# Next, let's load the models that we will use to generate our transferable adversarial examples. We will be using a diverse set of models:
#
# 1. **A Resnet model**, similar to the MiniWideResnet model you used in previous sections.
#    * Test set accuracy: 97.61%
# 2. **A CNN model**, which is a simple model that has three convolutional layers and three dense layers.
#    * Test set accuracy: 96.74%
# 3. **An MLP model** which contains three standard fully connected layers.
#    * Test set accuracy: 94.27%
#
# Code for how we trained each of these models can be found [here](https://github.com/zroe1/xlab-ai-security/tree/main/models/MNIST_ensemble). To load the models on your computer, you can run the cells below.

# %%
from huggingface_hub import hf_hub_download
from xlab.models import (
    ConvolutionalMNIST,
    ResNetMNIST,
    BasicBlockMNIST,
    FeedforwardMNIST,
)

hf_path = "uchicago-xlab-ai-security/mnist-ensemble"

# resnet model
model_path = hf_hub_download(repo_id=hf_path, filename="mnist_wideresnet.pth")
white_box1 = torch.load(model_path, map_location=device, weights_only=False)

# cnn model
model_path = hf_hub_download(repo_id=hf_path, filename="mnist_simple_cnn.pth")
white_box2 = torch.load(model_path, map_location=device, weights_only=False)

# mlp model
model_path = hf_hub_download(repo_id=hf_path, filename="mnist_mlp.pth")
white_box3 = torch.load(model_path, map_location=device, weights_only=False)
# Out:
# mnist_wideresnet.pth:   0%|          | 0.00/693k [00:00<?, ?B/s]
# mnist_simple_cnn.pth:   0%|          | 0.00/432k [00:00<?, ?B/s]
# mnist_mlp.pth:   0%|          | 0.00/166k [00:00<?, ?B/s]

# %% [markdown]
# ## Loading Black-Box Models
#
# Now we can load our black box model which we will attempt to attack in this notebook. You will interact with this model through our Python package and you won't be able to see anything about the model architecture. You will only be able to call `model.predict` to get model predictions for a set of images and `model.predict_proba` to get model probabilities for a set of images.

# %%
from xlab.models import BlackBox

# Load the black box model (downloads automatically)
black_box = xlab.utils.load_black_box_model("mnist-black-box")

# Make predictions (model details are hidden)
predictions = black_box.predict(mnist_images)
probabilities = black_box.predict_proba(mnist_images)

print(f"predictions={predictions}")
print(f"probabilities.shape={probabilities.shape}")
# Out:
# mnist_black_box_mlp.pth:   0%|          | 0.00/842k [00:00<?, ?B/s]
# predictions=tensor([7, 2, 1, 0, 4, 1, 4, 9, 6, 9, 0, 2, 9, 0, 1, 5, 9, 7, 3, 4, 9, 6, 6, 5,
#         4, 0, 7, 4, 0, 1, 3, 1, 3, 0, 7, 2, 7, 1, 3, 1, 1, 7, 4, 2, 3, 5, 1, 2,
#         4, 4, 6, 3, 5, 5, 6, 0, 4, 1, 9, 5, 7, 8, 4, 3, 7, 4, 2, 4, 3, 0, 7, 0,
#         2, 7, 1, 7, 3, 2, 9, 7, 7, 6, 2, 7, 8, 4, 7, 3, 6, 1, 3, 6, 4, 3, 1, 4,
#         1, 7, 6, 9])
# probabilities.shape=torch.Size([100, 10])

# %% [markdown]
# ## Task #1: Ensemble Loss
#
# Given an array of $k$ alpha values and $k$ models you will compute the weighted cross entropy loss by the following equation:
#
# $$
# \mathrm{argmin}_\delta \  \  D(\delta) + \sum_{i=1}^k \alpha_i \cdot \ell_i(x + \delta)
# $$
#
#
# <details>
# <summary>🔐 <b>Solution for Task #1</b></summary>
#
# ```python
# def ensemble_loss(alphas, models, img, target):
#     """
#     Computes weighted ensemble loss across multiple models.
#
#     Args:
#         alphas (list): weight coefficients for each model in the ensemble
#         models (list): PyTorch models to compute ensemble loss over
#         img [1, 1, 28, 28]: input MNIST image tensor with batch dimension
#         target [1]: class label tensor containing single target class
#
#     Returns (Tensor): weighted sum of CrossEntropyLoss across all models
#     """
#
#     loss = torch.tensor(0.0).to(device)
#     loss_fn = torch.nn.CrossEntropyLoss()
#
#     # 1. iterate over alphas and models
#     for alpha, model in zip(alphas, models):
#
#         # 2. calculate weighted loss for each model
#         out = model(img)
#         model_loss = loss_fn(out, target)
#         loss += alpha * model_loss
#
#     return loss
#
# ```
#
# </details>

# %%
def ensemble_loss(alphas, models, img, target):
    """
    Computes weighted ensemble loss across multiple models.

    Args:
        alphas (list): weight coefficients for each model in the ensemble
        models (list): PyTorch models to compute ensemble loss over
        img [1, 1, 28, 28]: input MNIST image tensor with batch dimension
        target [1]: class label tensor containing single target class

    Returns (Tensor): weighted sum of CrossEntropyLoss across all models
    """

    loss = torch.tensor(0.0).to(device)
    loss_fn = torch.nn.CrossEntropyLoss()

    ######### YOUR CODE STARTS HERE #########
    # 1. iterate over alphas and models
    for alpha, model in zip(alphas, models):

        # 2. calculate weighted loss for each model
        out = model(img)
        model_loss = loss_fn(out, target)
        loss += alpha * model_loss
    ########## YOUR CODE ENDS HERE ##########

    return loss

# %%
img = mnist_images[0:1].to(device)
alphas = [1 / 3, 1 / 3, 1 / 3]
models = [white_box1, white_box2, white_box3]

example_losses = []
with torch.no_grad():
    for i in range(10):
        example_loss = ensemble_loss(alphas, models, img, torch.tensor([i]).to(device))
        example_losses.append(example_loss.item())
print(example_losses)

xlab.tests.ensemble.task1(example_losses)
# Out:
# [13.770523071289062, 15.317306518554688, 8.956832885742188, 7.667976379394531, 18.443864822387695, 14.074539184570312, 27.119890213012695, 0.0033627948723733425, 12.956640243530273, 8.222661972045898]
# ============================= test session starts ==============================
# collecting ... collected 15 items / 4 deselected / 11 selected
#
# ../usr/local/lib/python3.12/dist-packages/xlab/tests/ensemble.py::test_mnist_class_0_loss PASSED [  9%]
# ../usr/local/lib/python3.12/dist-packages/xlab/tests/ensemble.py::test_mnist_class_1_loss PASSED [ 18%]
# ../usr/local/lib/python3.12/dist-packages/xlab/tests/ensemble.py::test_mnist_class_2_loss PASSED [ 27%]
# ../usr/local/lib/python3.12/dist-packages/xlab/tests/ensemble.py::test_mnist_class_3_loss PASSED [ 36%]
# ../usr/local/lib/python3.12/dist-packages/xlab/tests/ensemble.py::test_mnist_class_4_loss PASSED [ 45%]
# ../usr/local/lib/python3.12/dist-packages/xlab/tests/ensemble.py::test_mnist_class_5_loss PASSED [ 54%]
# ../usr/local/lib/python3.12/dist-packages/xlab/tests/ensemble.py::test_mnist_class_6_loss PASSED [ 63%]
# ../usr/local/lib/python3.12/dist-packages/xlab/tests/ensemble.py::test_mnist_class_7_loss PASSED [ 72%]
# ../usr/local/lib/python3.12/dist-packages/xlab/tests/ensemble.py::test_mnist_class_8_loss PASSED [ 81%]
# ../usr/local/lib/python3.12/dist-packages/xlab/tests/ensemble.py::test_mnist_class_9_loss PASSED [ 90%]
# ../usr/local/lib/python3.12/dist-packages/xlab/tests/ensemble.py::test_mnist_losses_count PASSED [100%]
#
# =============================== warnings summary ===============================
# ../usr/local/lib/python3.12/dist-packages/_pytest/config/__init__.py:1290
#   /usr/local/lib/python3.12/dist-packages/_pytest/config/__init__.py:1290: PytestAssertRewriteWarning: Module already imported so cannot be rewritten; anyio
#     self._mark_plugins_for_rewrite(hook, disable_autoload)
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# ================= 11 passed, 4 deselected, 1 warning in 0.07s ==================
# ✅ All checks passed!

# %% [markdown]
# ## Task #2: Ensemble Attack
#
# Now you should be in a good position to complete the ensemble attack. This is exactly the same as PGD, but instead of using a typical loss like Cross Entropy, you will be using the ensemble loss you implemented in `Task #1`. Note that in the original paper, the authors implement something more similar to Carlini-Wagner with a hyperparameter $\lambda$ which controls how much the distance metric is weighted in the final loss. For simplicity and compatibility with our tests you should use the update rule below:
#
# $$
# x'_i =  \mathrm{clip}_\epsilon(x + \alpha \cdot \mathrm{sign}(\nabla \mathrm{ensemble\_loss}_{F,t}(x'_{i-1})))
# $$
#
# For the purpose of not making this too difficult, we have allowed a very high $\epsilon$ value. While one may expect $\epsilon=24/255$ to yield some absurd results, in practice this is somewhat reasonable because of the high-contrast nature of the dataset. Also, because it is a gray-scale image, there are fewer pixel values to work with so the total distance of the perturbation (if you take the absolute value and sum) will be probably less than $\epsilon=12/255$ for a color image.
#
# <b>Note:</b> You may use our solution to the clip function from the PGD notebook by calling `xlab.utils.clip`. You can also implement this functionality again within this notebook if you prefer.
#
#
# <details>
# <summary>🔐 <b>Solution for Task #2</b></summary>
#
# ```python
# def ensemble_attack_PGD(alphas, models, img, target, epsilon=24/255, alpha=2/255, num_iters=50):
#     """
#     Generates adversarial examples using Projected Gradient Descent (PGD)
#     with ensemble loss.
#
#     Args:
#         alphas (list): weight coefficients for each model in the ensemble
#         models (list): PyTorch models to compute ensemble loss over
#         img [1, 1, 28, 28]: input MNIST image tensor with batch dimension
#         target [1]: class label tensor containing target class for attack
#         epsilon (float): maximum allowed perturbation magnitude, defaults to 24/255
#         alpha (float): step size for each iteration, defaults to 2/255
#         num_iters (int): number of iterative steps to perform, defaults to 50
#
#     Returns [1, 1, 28, 28]: adversarially perturbed image tensor with
#         perturbations bounded by epsilon and pixel values clamped to [0, 1]
#     """
#
#     img_original = img.clone()
#     adv_img = xlab.utils.add_noise(img)
#
#     # 1. loop over num_iters
#     for _ in range(num_iters):
#         adv_img.requires_grad=True
#
#          # 2. calculate grad of ensemble loss w.r.t. image
#         loss = ensemble_loss(alphas, models, adv_img, target)
#         loss.backward()
#         grad = adv_img.grad.data
#
#         # 3. perturb the image using the signs of the gradient
#         adv_img.requires_grad_(False)
#         adv_img -= alpha * torch.sign(grad)
#
#         # 4. clamp the image within epsilon distance and between 0 and 1
#         adv_img = xlab.utils.clip(adv_img, img_original, epsilon)
#
#     return adv_img
# ```
#
# </details>

# %%
def ensemble_attack_PGD(
    alphas, models, img, target, epsilon=24 / 255, alpha=2 / 255, num_iters=50
):
    """
    Generates adversarial examples using Projected Gradient Descent (PGD)
    with ensemble loss.

    Args:
        alphas (list): weight coefficients for each model in the ensemble
        models (list): PyTorch models to compute ensemble loss over
        img [1, 1, 28, 28]: input MNIST image tensor with batch dimension
        target [1]: class label tensor containing target class for attack
        epsilon (float): maximum allowed perturbation magnitude, defaults to 24/255
        alpha (float): step size for each iteration, defaults to 2/255
        num_iters (int): number of iterative steps to perform, defaults to 50

    Returns [1, 1, 28, 28]: adversarially perturbed image tensor with
        perturbations bounded by epsilon and pixel values clamped to [0, 1]
    """

    img_original = img.clone()
    adv_img = xlab.utils.add_noise(img)

    ######### YOUR CODE STARTS HERE #########
    # 1. loop over num_iters
    for idx in range(num_iters):
      # 2. calculate grad of ensemble loss w.r.t. image
      adv_img.requires_grad_(True)
      loss_val = ensemble_loss(alphas, models, adv_img, target)
      loss_val.backward()

      # 3. perturb the image using the signs of the gradient
      adv_img.requires_grad_(False)
      adv_img -= alpha * torch.sign(adv_img.grad.data)

      # 4. clamp the image within epsilon distance and between 0 and 1
      adv_img = xlab.utils.clip(adv_img, img_original, epsilon)
    ########## YOUR CODE ENDS HERE ##########

    return adv_img

# %% [markdown]
# As a first check, you should see that the targeted attack on the image below should succeed when the target class is 2. If this does not work, we recommend going back and double checking your code before running the test in the next section of the notebook.

# %%
img = mnist_images[2:3].to(device)
adv_img = ensemble_attack_PGD(alphas, models, img, torch.tensor([2]).to(device))
xlab.utils.show_grayscale_image(adv_img[0], "Targeted attack on image of 1")
predictions = black_box.predict(adv_img)
print(f"Black box predicts {predictions.item()}")
# Out:
# Black box predicts 2

# %% [markdown]
# # Testing Your Attack
#
# Transferring targeted adversarial examples is difficult. To make things easier for you we have identified a list of 5 images which we were able to generate transferable adversarial images for quite easily. For testing, you can run the cell below which will run your attack on these 5 images with the target class 3 (none of the images in `breakable_imgs` has a clean label of 3). To pass the test below, four out of five of the attacks must be successful.

# %%
breakable_idxs = [5, 11, 14, 15, 17]
target_class = 3

breakable_imgs = [mnist_images[i : i + 1].to(device) for i in breakable_idxs]
adv_imgs = []

for img in breakable_imgs:
    adv_img = ensemble_attack_PGD(
        alphas, models, img, torch.tensor([target_class]).to(device)
    )
    adv_imgs.append(adv_img)

    predictions = black_box.predict(adv_img)
    if predictions.item() == target_class:
        print(f"Attack was successful! Predicted class = {target_class}")
    else:
        print(
            f"Attack was unsuccessful. Predicted class = {predictions.item()} and target class = {target_class}"
        )
# Out:
# Attack was successful! Predicted class = 3
# Attack was successful! Predicted class = 3
# Attack was successful! Predicted class = 3
# Attack was successful! Predicted class = 3
# Attack was successful! Predicted class = 3

# %%
xlab.tests.ensemble.task2(adv_imgs, black_box)
# Out:
# ============================= test session starts ==============================
# collecting ... collected 15 items / 11 deselected / 4 selected
#
# ../usr/local/lib/python3.12/dist-packages/xlab/tests/ensemble.py::test_mnist_images_count PASSED [ 25%]
# ../usr/local/lib/python3.12/dist-packages/xlab/tests/ensemble.py::test_mnist_images_shape PASSED [ 50%]
# ../usr/local/lib/python3.12/dist-packages/xlab/tests/ensemble.py::test_model_provided PASSED [ 75%]
# ../usr/local/lib/python3.12/dist-packages/xlab/tests/ensemble.py::test_mnist_classification_to_3 PASSED [100%]
#
# =============================== warnings summary ===============================
# ../usr/local/lib/python3.12/dist-packages/_pytest/config/__init__.py:1290
# ../usr/local/lib/python3.12/dist-packages/_pytest/config/__init__.py:1290
#   /usr/local/lib/python3.12/dist-packages/_pytest/config/__init__.py:1290: PytestAssertRewriteWarning: Module already imported so cannot be rewritten; anyio
#     self._mark_plugins_for_rewrite(hook, disable_autoload)
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# ================= 4 passed, 11 deselected, 2 warnings in 0.03s =================
# ✅ All checks passed!

# %% [markdown]
# ## Further Exploration
#
# If you are interested, we encourage you to play around with the attack above to see if you can successfully transfer targeted attacks to other classes or to other images in the testing set. Although you should be able to do better than our solution (ours is the bare minimum), you should not expect to be able to complete this attack for every image for every class. In general, these kinds of targeted attacks are difficult to pull off and often require a more involved solution.
#
# Ideas for how to improve the attack:
#
# 1. Tune the alpha values and see how different weights influence your chance of success. You should find that different weights significantly affect success rates.
# 2. Try a more sophisticated optimization approach. Instead of using `alpha` to update the image, try using a PyTorch optimizer.
# 3. Go back to the [original paper](https://arxiv.org/pdf/1611.02770) and try to implement something closer to their "Optimization based approach"
